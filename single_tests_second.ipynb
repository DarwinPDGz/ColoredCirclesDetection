# %%
from circledetectexperimental import CircleDetect, CircleDetectInstance
import os

# %%
path = []

# path.append('c:/Users/Darwin/Documents/Wayang_related/imgprocessing/sita_initial_wflash/threequarters/pts/')
# path.append('c:/Users/Darwin/Documents/Wayang_related/imgprocessing/Subali/ptf/')
# path.append('c:/Users/Darwin/Documents/Wayang_related/imgprocessing/laksmana/mf/')
# path.append('c:/Users/Darwin/Documents/Wayang_related/imgprocessing/Wibhisana/ptf/')
# path.append('c:/Users/Darwin/Documents/Wayang_related/imgprocessing/Anggada/ptf/')
# path.append('c:/Users/Darwin/Documents/Wayang_related/imgprocessing/Anila/lptf/')

path.append('c:/Users/Darwin/Documents/Wayang_related/imgprocessing/rahwana/lptf/')
# path.append('c:/Users/Darwin/Documents/Wayang_related/imgprocessing/rahwana/df/')
# path.append('c:/Users/Darwin/Documents/Wayang_related/imgprocessing/rama/ptf/')
# path.append('c:/Users/Darwin/Documents/Wayang_related/imgprocessing/rama/mf/')
# path.append('c:/Users/Darwin/Documents/Wayang_related/imgprocessing/rama/pts/')
# path.append('c:/Users/Darwin/Documents/Wayang_related/imgprocessing/laksmana/df/')
# path.append('c:/Users/Darwin/Documents/Wayang_related/imgprocessing/hanuman/ptf/')

# path.append('c:/Users/Darwin/Documents/Wayang_related/imgprocessing/rahwana/df/') 

print(path)
# Out:
# ['c:/Users/Darwin/Documents/Wayang_related/imgprocessing/rahwana/lptf/']

# %%
dict_of_dirs = {}

for i in range(len(path)):
    list = os.listdir(path[i])
    dict_of_dirs[i] = list

# %%
dict_of_real_paths = {}

for i in range(len(path)):
    real_path = []
    for j in range(len(dict_of_dirs[i])):
        real_path.append(path[i] + dict_of_dirs[i][j])
    dict_of_real_paths[i] = real_path

# %%
dict_of_real_paths[0][4]
# Out:
# 'c:/Users/Darwin/Documents/Wayang_related/imgprocessing/rahwana/lptf/20241113_123143340_iOS.jpg'

# %%
dict_of_real_paths[0][5]
# Out:
# 'c:/Users/Darwin/Documents/Wayang_related/imgprocessing/rahwana/lptf/20241113_123149674_iOS.jpg'

# %%
first_list_of_params = {
    'real_path': dict_of_real_paths[0][13],
    'minDist': 15,
    'param1': 70,
    'param2': 20,
    'minRadius': 15,
    'maxRadius': 30,
    'ptp': 80,
    'tolerance': 8,
    'detectFULL': True,
    'cct': 2,
    'range_type': 2,
    'set_order_f':CircleDetect.SET_ORDER_F_RAWANA,
    'set_order_b':CircleDetect.SET_ORDER_B_RAWANA,
    'arrayVersion': 1}

first_instance = CircleDetectInstance(
    first_list_of_params['real_path'],
    cct=first_list_of_params['cct'], 
    detectFULL=first_list_of_params['detectFULL'],
    range_type=first_list_of_params['range_type'], 
    set_order_f=first_list_of_params['set_order_f'], 
    set_order_b=first_list_of_params['set_order_b'], 
    arrayVersion=first_list_of_params['arrayVersion'], autoparam=True, debug=True, single=True, isfront=True)
# Out:
# detectFULL
# (1, 28, 3)
# radius list [16 17 17 18 19 20 20 20 20 20 20 20 20 21 21 21 21 21 21 22 22 22 22 22
#  22 22 22 24]
# radius mode [16, 17, 18, 19, 20, 21, 22, 24]
# radius counter [1, 2, 1, 1, 8, 6, 8, 1]
# which radius mode 22 20
# minmode:  18
# maxmode:  24
# re_parameter2 (done, setting radius):  30
# re_minimumRadius:  18
# re_maximumRadius:  24
# re_parameter2 (NOT done, instance is autoparamed):  29
# re_parameter2 (NOT done, instance is autoparamed):  28
# re_parameter2 (NOT done, instance is autoparamed):  27
# re_parameter2 (NOT done, instance is autoparamed):  26
# re_parameter2 (NOT done, instance is autoparamed):  25
# detectFULL
# (1, 25, 3)
# ratio
# h:  0.5270150575730735
# l:  0.20637732506643047
# s:  0.2178919397697077
# [19 20 18 21 17] (5,)
# alt_filter_circles failed: 0 0
# ratio
# h:  0.9522673031026253
# l:  0.8202068416865553
# s:  0.747016706443914
# [115 116 117 114 113] (5,)
# alt_filter_circles passed: 1
# ratio
# h:  0.9803350327749454
# ...

# %%
#check autoparam params

set_param2 = first_instance.re_parameter2
set_minRadius = first_instance.minimumRadius
set_maxRadius = first_instance.maximumRadius

print('set_param2: ', set_param2)
print('set_minRadius: ', set_minRadius)
print('set_maxRadius: ', set_maxRadius)

# %%
first_instance.cd.show_initial_circles()

# %%
first_instance.cd.show_processed_image()

# %%
vf, vb, ccimg = first_instance.cd.process_image(save=True, path=path[0]+ 'processed/' +str(dict_of_dirs[0][4]))

# %%
if os.path.isfile(path[0]+ 'processed/'+str(dict_of_dirs[0][1])+'.txt'):
    print('file exists')
else:
    open(path[0]+ 'processed/'+str(dict_of_dirs[0][1])+'.txt', 'x')
    
f = open(path[0]+ 'processed/'+str(dict_of_dirs[0][1])+'.txt', 'w')
f.write('vf: '+str(vf)+'\n')
f.write('vb: '+str(vb)+'\n')
f.close()
